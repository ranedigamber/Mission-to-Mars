# %%
# Dependencies
from bs4 import BeautifulSoup
import requests

# %%
# URL of page to be scraped
url = 'https://newjersey.craigslist.org/search/sss?sort=rel&query=guitar%20PRS'

# %%
# Retrieve page with the requests module
response = requests.get(url)

# %%
print(response.text)
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#
# 	<meta charset="UTF-8">
# 	<meta http-equiv="X-UA-Compatible" content="IE=Edge">
# 	<meta name="viewport" content="width=device-width,initial-scale=1">
# 	<meta property="og:site_name" content="craigslist">
# 	<meta name="twitter:card" content="preview">
# 	<meta property="og:title" content="north jersey for sale &quot;guitar PRS&quot; - craigslist">
# 	<meta name="description" content="north jersey for sale &quot;guitar PRS&quot; - craigslist">
# 	<meta property="og:description" content="north jersey for sale &quot;guitar PRS&quot; - craigslist">
# 	<meta property="og:url" content="https://newjersey.craigslist.org/search/sss?query=guitar+prs">
# 	<meta name="smartbanner:api" content="true">
# 	<meta name="smartbanner:title" content="the craigslist app">
# 	<meta name="smartbanner:author" content="what&#39;s old is new">
# 	<meta name="smartbanner:icon-apple" content="/images/app_icon.png">
# ...

# %%
# Create BeautifulSoup object; parse with 'html.parser'
soup = BeautifulSoup(response.text, 'html.parser')

# %%
# Examine the results, then determine element that contains sought info
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width,initial-scale=1" name="viewport"/>
#   <meta content="craigslist" property="og:site_name"/>
#   <meta content="preview" name="twitter:card"/>
#   <meta content='north jersey for sale "guitar PRS" - craigslist' property="og:title"/>
#   <meta content='north jersey for sale "guitar PRS" - craigslist' name="description"/>
#   <meta content='north jersey for sale "guitar PRS" - craigslist' property="og:description"/>
#   <meta content="https://newjersey.craigslist.org/search/sss?query=guitar+prs" property="og:url"/>
#   <meta content="true" name="smartbanner:api"/>
#   <meta content="the craigslist app" name="smartbanner:title"/>
#   <meta content="what's old is new" name="smartbanner:author"/>
#   <meta content="/images/app_icon.png" name="smartbanner:icon-apple"/>
# ...

# %%
# results are returned as an iterable list
results = soup.find_all('li', class_="result-row")

# %%
# Loop through returned results
for result in results:
    # Error handling
    try:
        # Identify and return title of listing
        title = result.find('a', class_="result-title").text
        # Identify and return price of listing
        price = result.a.span.text
        # Identify and return link to listing
        link = result.a['href']

        # Print results only if title, price, and link are available
        if (title and price and link):
            print('-------------')
            print(title)
            print(price)
            print(link)
    except AttributeError as e:
        print(e)
# Out:
# -------------
# PRS Mira SE guitar
# $525
# https://newjersey.craigslist.org/msg/d/succasunna-prs-mira-se-guitar/7518581337.html
# -------------
# Guitar - Ernie Ball Musicman Cutlass BFR Smoked Chrome - only 56 made!
# $2,500
# https://newjersey.craigslist.org/msg/d/tallman-guitar-ernie-ball-musicman/7507172112.html
# -------------
# Gretsch G2622T electric guitar
# $419
# https://newjersey.craigslist.org/msg/d/oradell-gretsch-g2622t-electric-guitar/7515270131.html
# -------------
# 2012 PRS USA Prototype / Artist Proof - Nick Cantanese Single Cut
# $0
# https://newjersey.craigslist.org/msg/d/paramus-2012-prs-usa-prototype-artist/7512971569.html
# -------------
# PRS SE Soapbar I, Original Single Cutaway
# $599
# https://newjersey.craigslist.org/msg/d/orangeburg-prs-se-soapbar-original/7505185690.html
# -------------
# fs/ft custom made telecaster by performance of hollywood
# $2,199
# https://newjersey.craigslist.org/msg/d/hopatcong-fs-ft-custom-made-telecaster/7515609747.html
# ...

# %%
result.a
# Out:
# <a class="result-image gallery" data-ids="3:00Y0Y_ccwtsAjzOPbz_0dL0t2,3:00z0z_hWWz48dseLOz_0dL0t2,3:00Y0Y_6z0WwkLQfXQz_0dL0t2,3:00J0J_dcbEHrQl3jNz_0dL0t2,3:00r0r_6Wl9CYoRcuOz_0dL0t2,3:00f0f_ftLUMARdZccz_0dL0t2,3:00O0O_6ufUPcWLelfz_0dL0t2,3:00k0k_baWqwDp6cMxz_0dL0t2,3:00b0b_7WHtJbZBaVEz_0dL0t2,3:01616_57uSH6eHN4Zz_0dL0t2,3:00S0S_enoGeQokZWqz_0dL0t2" href="https://cnj.craigslist.org/msg/d/trenton-knaggs-2016-severn-hss-t2/7493040174.html">
# <span class="result-price">$4,200</span>
# </a>

# %%
# Note that if you print out "result" there is a "time" tag, too.
print(result)
# Out:
# <li class="result-row" data-pid="7493040174" data-repost-of="7148777703">
# <a class="result-image gallery" data-ids="3:00Y0Y_ccwtsAjzOPbz_0dL0t2,3:00z0z_hWWz48dseLOz_0dL0t2,3:00Y0Y_6z0WwkLQfXQz_0dL0t2,3:00J0J_dcbEHrQl3jNz_0dL0t2,3:00r0r_6Wl9CYoRcuOz_0dL0t2,3:00f0f_ftLUMARdZccz_0dL0t2,3:00O0O_6ufUPcWLelfz_0dL0t2,3:00k0k_baWqwDp6cMxz_0dL0t2,3:00b0b_7WHtJbZBaVEz_0dL0t2,3:01616_57uSH6eHN4Zz_0dL0t2,3:00S0S_enoGeQokZWqz_0dL0t2" href="https://cnj.craigslist.org/msg/d/trenton-knaggs-2016-severn-hss-t2/7493040174.html">
# <span class="result-price">$4,200</span>
# </a>
# <div class="result-info">
# <span class="icon icon-star" role="button">
# <span class="screen-reader-text">favorite this post</span>
# </span>
# <time class="result-date" datetime="2022-06-29 16:42" title="Wed 29 Jun 04:42:21 PM">Jun 29</time>
# <h3 class="result-heading">
# ...

# %%
# So, can we access what's in this time tag by access result.time?
# You bet!
result.time
# Out:
# <time class="result-date" datetime="2022-06-29 16:42" title="Wed 29 Jun 04:42:21 PM">Jun 29</time>

# %%
# And if wanted to get what's in the "datetime" parameter, rather than what's in the text between
#   the opening and closing "time" tags?  Beautiful Soup lets us access tag parameters by key!
result.time['datetime']
# Out:
# '2022-06-29 16:42'
