# %%
# Dependencies
from bs4 import BeautifulSoup
import requests
import pymongo

# %%
# Initialize PyMongo to work with MongoDBs
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# %%
# Define database and collection
db = client.nhl_db
collection = db.articles

# %%
# URL of page to be scraped
url = 'https://www.nhl.com/news'

# Retrieve page with the requests module
response = requests.get(url)
# Create BeautifulSoup object; parse with 'html.parser'
soup = BeautifulSoup(response.text, 'html.parser')

# %%
# Retrieve the parent divs for all articles
results = soup.find_all('div', class_='article-item__top')

# loop over results to get article data
for result in results:
    # scrape the article header 
    header = result.find('h1', class_='article-item__headline').text
    
    # scrape the article subheader
    subheader = result.find('h2', class_='article-item__subheader').text
    
    # scrape the datetime
    datetime = result.find('span', class_='article-item__date')['data-date'] 
    
    # get only the date from the datetime
    date = datetime.split('T')[0]
    
    # print article data
    print('-----------------')
    print(header)
    print(subheader)
    print(date)

    # Dictionary to be inserted into MongoDB
    post = {
        'header': header,
        'subheader': subheader,
        'date': date,
    }

    # Insert dictionary into MongoDB as a document
    collection.insert_one(post)
# Out:
# -----------------
# Inside look at Boston Bruins
# Bergeron, Krejci return to give new coach Montgomery spark with key players out to start season
# 2022-08-10
# -----------------
# Pacioretty of Hurricanes to have surgery, likely out first half of season
# Forward will need six months to recover for torn Achilles, was acquired from Golden Knights on July 13
# 2022-08-09
# -----------------
# Mailbag: Robertson's future, Islanders offseason, best in Metropolitan
# NHL.com's Dan Rosen answers weekly questions
# 2022-08-10
# -----------------
# Trouba named Rangers captain, first since McDonagh in 2018
# Defenseman 28th player to hold title in New York history
# 2022-08-09
# -----------------
# Three questions facing Boston Bruins
# Marchand, McAvoy injuries, Montgomery's impact as new coach among concerns
# 2022-08-10
# -----------------
# NHL Free Agent Tracker
# Complete list of signings by team, available players
# 2022-08-09
# -----------------
# DeBoer talks joining Stars, Pavelski as coach in Q&A with NHL.com
# Discusses time working for Golden Knights, leading Sharks, Devils to Stanley Cup Final
# 2022-08-10
# -----------------
# World Junior Championship roundup: Czechia defeats Slovakia on late goal
# United States set to start tournament against Germany; Finland tops Latvia
# 2022-08-09
# -----------------
# Top prospects for Boston Bruins
# Lysell, Studnicka on cusp, Beecher likely to start in AHL
# 2022-08-10
# -----------------
# Fantasy hockey mock draft 1.0
# Results of first standard-league simulation for 2022-23; season preview podcasts
# 2022-08-09
# -----------------
# 2022 World Junior Championship schedule
# Canada set to play against Latvia in Edmonton
# 2022-08-09
# -----------------
# State Your Case: Can Ovechkin score 50 again?
# NHL.com writers debate whether Capitals forward can reach mark this season at age 37
# 2022-08-09
# -----------------
# Boston Bruins fantasy projections for 2022-23
# Pastrnak remains elite option; Swayman breakout candidate; Hall could be bargain
# 2022-08-10
# -----------------
# Bergeron, Krejci each signs one-year contract with Bruins
# Captain back for 19th season with Boston; fellow center returns after playing in Czech Republic
# 2022-08-09
# -----------------
# Necas signs two-year contract with Hurricanes
# Restricted free agent forward gets $6 million, had 40 points last season
# 2022-08-09
# -----------------
# Top remaining NHL unrestricted free agents include Kadri, Kessel
# Stastny, Subban also available
# 2022-08-08
# -----------------
# Askarov working way up depth chart for Predators
# Goalie expected to play in AHL this season, will be 'really good player for us'
# 2022-08-10
# -----------------
# Bergeron's fire still strong, ready to do 'something special' with Bruins
# 37-year-old center returns to Boston for 19th season, teams up with Krejci again
# 2022-08-08
# -----------------
# McDonagh excited by opportunity to play for Predators
# Defenseman was acquired from Lightning, sees Nashville as 'hungry for more and I want to be a part of it'
# 2022-08-09
# -----------------
# Inside look at Arizona Coyotes
# Focused on extended rebuild entering first season at Arizona State University
# 2022-08-09
# -----------------
# Three questions facing Arizona Coyotes
# Chychrun bouncing back amid trade rumors, 14-game road trip among concerns
# 2022-08-09
# -----------------
# Hasek looks back at trade to Sabres that changed NHL career, life
# 30 years later, Hall of Fame goalie discusses emergence in 'my second home'
# 2022-08-07
# -----------------
# Zacha signs one-year contract with Bruins, avoids arbitration
# Forward gets $3.5 million, had hearing scheduled for Thursday
# 2022-08-09
# -----------------
# Top prospects for Arizona Coyotes
# Cooley No. 3 pick in 2022 draft; McBain could see time in NHL this season
# 2022-08-09
# -----------------
# Roy signs five-year, $15 million contract with Golden Knights
# Forward was restricted free agent, had NHL career-high 39 points last season
# 2022-08-08
# -----------------
# 2022 NHL Draft first-round pick signings tracker
# Status of 32 players chosen in opening round
# 2022-07-18
# -----------------
# Giroux, Gaudreau among new faces in new places for 2022-23 NHL season
# Flyers host Senators on Nov. 12; Blue Jackets to visit Flames on Jan. 23
# 2022-08-08
# -----------------
# Crouse signs five-year contract with Coyotes, avoids arbitration
# Forward had hearing scheduled for Monday
# 2022-08-08
# -----------------
# Trouba congratulated by teammates after being named Rangers captain
# Panarin, Zibanejad among those to rally around defenseman on social media
# 2022-08-09
# -----------------
# Arizona Coyotes fantasy projections for 2022-23
# Keller most valuable overall player; Schmaltz worth monitoring in late rounds
# 2022-08-09

# %%
# Display the MongoDB records created above
articles = db.articles.find()
for article in articles:
    print(article)
# Out:
# {'_id': ObjectId('62f300dbc014e15b48e267a7'), 'header': 'Inside look at Arizona Coyotes', 'subheader': 'Focused on extended rebuild entering first season at Arizona State University', 'date': '2022-08-09'}
# {'_id': ObjectId('62f300dbc014e15b48e267a8'), 'header': 'Trouba named Rangers captain, first since McDonagh in 2018', 'subheader': 'Defenseman 28th player to hold title in New York history', 'date': '2022-08-09'}
# {'_id': ObjectId('62f300dbc014e15b48e267a9'), 'header': "3 'Star' keys to success for United States against Germany at WJC", 'subheader': 'NHL Network analyst Starman praises U.S. defensemen, says staying alert will be vital in opening game', 'date': '2022-08-08'}
# {'_id': ObjectId('62f300dbc014e15b48e267aa'), 'header': 'State Your Case: Can Ovechkin score 50 again?', 'subheader': 'NHL.com writers debate whether Capitals forward can reach mark this season at age 37', 'date': '2022-08-09'}
# {'_id': ObjectId('62f300dbc014e15b48e267ab'), 'header': "Bergeron's fire still strong, ready to do 'something special' with Bruins", 'subheader': '37-year-old center returns to Boston for 19th season, teams up with Krejci again', 'date': '2022-08-08'}
# {'_id': ObjectId('62f300dbc014e15b48e267ac'), 'header': 'NHL Free Agent Tracker', 'subheader': 'Complete list of signings by team, available players', 'date': '2022-08-09'}
# {'_id': ObjectId('62f300dbc014e15b48e267ad'), 'header': 'World Junior Championship roundup: Czechia defeats Slovakia on late goal', 'subheader': 'United States set to start tournament against Germany', 'date': '2022-08-09'}
# {'_id': ObjectId('62f300dbc014e15b48e267ae'), 'header': 'Three questions facing Arizona Coyotes', 'subheader': 'Chychrun bouncing back amid trade rumors, 14-game road trip among concerns', 'date': '2022-08-09'}
# {'_id': ObjectId('62f300dbc014e15b48e267af'), 'header': 'Necas signs two-year contract with Hurricanes', 'subheader': 'Restricted free agent forward gets $6 million, had 40 points last season', 'date': '2022-08-09'}
# {'_id': ObjectId('62f300dbc014e15b48e267b0'), 'header': 'McDonagh excited by opportunity to play for Predators', 'subheader': "Defenseman was acquired from Lightning, sees Nashville as 'hungry for more and I want to be a part of it'", 'date': '2022-08-09'}
# {'_id': ObjectId('62f300dbc014e15b48e267b1'), 'header': '2022 World Junior Championship schedule', 'subheader': 'United States opens against Germany on Tuesday, Canada plays Latvia on Wednesday in Edmonton', 'date': '2022-08-09'}
# {'_id': ObjectId('62f300dbc014e15b48e267b2'), 'header': 'Hasek looks back at trade to Sabres that changed NHL career, life', 'subheader': "30 years later, Hall of Fame goalie discusses emergence in 'my second home'", 'date': '2022-08-07'}
# {'_id': ObjectId('62f300dbc014e15b48e267b3'), 'header': 'Bennett takes Stanley Cup to Alberta hometown, hangs with Mounties', 'subheader': 'Avalanche assistant coach fundraises for Innisfail hockey on day with trophy', 'date': '2022-08-09'}
# {'_id': ObjectId('62f300dbc014e15b48e267b4'), 'header': 'Zacha signs one-year contract with Bruins, avoids arbitration', 'subheader': 'Forward gets $3.5 million, had hearing scheduled for Thursday', 'date': '2022-08-09'}
# {'_id': ObjectId('62f300dbc014e15b48e267b5'), 'header': 'Bergeron, Krejci each signs one-year contract with Bruins', 'subheader': 'Captain back for 19th season with Boston; fellow center returns after playing in Czech Republic', 'date': '2022-08-09'}
# {'_id': ObjectId('62f300dbc014e15b48e267b6'), 'header': 'Top remaining NHL unrestricted free agents include Kadri, Kessel', 'subheader': 'Stastny, Subban also available', 'date': '2022-08-08'}
# {'_id': ObjectId('62f300dbc014e15b48e267b7'), 'header': 'NHL mascots skate with fans at American Dream', 'subheader': 'Gritty, Bernie the St. Bernard join 11 others at New Jersey event', 'date': '2022-08-08'}
# {'_id': ObjectId('62f300dbc014e15b48e267b8'), 'header': 'Top prospects for Arizona Coyotes', 'subheader': 'Cooley No. 3 pick in 2022 draft; McBain could see time in NHL this season', 'date': '2022-08-09'}
# {'_id': ObjectId('62f300dbc014e15b48e267b9'), 'header': 'Roy signs five-year, $15 million contract with Golden Knights', 'subheader': 'Forward was restricted free agent, had NHL career-high 39 points last season', 'date': '2022-08-08'}
# {'_id': ObjectId('62f300dbc014e15b48e267ba'), 'header': 'Giroux, Gaudreau among new faces in new places for 2022-23 NHL season', 'subheader': 'Flyers host Senators on Nov. 12; Blue Jackets to visit Flames on Jan. 23', 'date': '2022-08-08'}
# {'_id': ObjectId('62f300dbc014e15b48e267bb'), 'header': 'Arizona Coyotes fantasy projections for 2022-23', 'subheader': 'Keller most valuable overall player; Schmaltz worth monitoring in late rounds', 'date': '2022-08-09'}
# {'_id': ObjectId('62f300dbc014e15b48e267bc'), 'header': 'Crouse signs five-year contract with Coyotes, avoids arbitration', 'subheader': 'Forward had hearing scheduled for Monday', 'date': '2022-08-08'}
# {'_id': ObjectId('62f300dbc014e15b48e267bd'), 'header': 'Trouba congratulated by teammates after being named Rangers captain', 'subheader': 'Panarin, Zibanejad among those to rally around defenseman on social media', 'date': '2022-08-09'}
# {'_id': ObjectId('62f300dbc014e15b48e267be'), 'header': '2022 World Junior Championship rosters', 'subheader': 'Red Wings top NHL with nine prospects; country, NHL affiliation for all players', 'date': '2022-08-08'}
# {'_id': ObjectId('62f300dbc014e15b48e267bf'), 'header': 'Inside look at Anaheim Ducks', 'subheader': 'Add veteran leadership to youthful core in effort to end playoff drought', 'date': '2022-08-08'}
# {'_id': ObjectId('62f300dbc014e15b48e267c0'), 'header': '2022 NHL Draft first-round pick signings tracker', 'subheader': 'Status of 32 players chosen in opening round', 'date': '2022-07-18'}
# {'_id': ObjectId('62f300dbc014e15b48e267c1'), 'header': 'Three questions facing Anaheim Ducks', 'subheader': "Klingberg's impact, similar production from Terry, Zegras among unknowns", 'date': '2022-08-08'}
# {'_id': ObjectId('62f300dbc014e15b48e267c2'), 'header': '2022 World Junior Championship predictions', 'subheader': 'NHL.com writers pick top three finishers, best player, top 2023 NHL Draft prospect', 'date': '2022-08-08'}
# {'_id': ObjectId('62f300dbc014e15b48e267c3'), 'header': 'Fantasy hockey mock draft 1.0', 'subheader': 'Results of first standard-league simulation for 2022-23; season preview podcasts', 'date': '2022-08-09'}
# {'_id': ObjectId('62f300dbc014e15b48e267c4'), 'header': 'Tullio poised to impress Oilers after learning value of hard work', 'subheader': 'Forward prospect had 86 points as Oshawa captain in OHL last season', 'date': '2022-08-09'}
# {'_id': ObjectId('62f33a3378f6fd03efc1aecd'), 'header': 'Inside look at Boston Bruins', 'subheader': 'Bergeron, Krejci return to give new coach Montgomery spark with key players out to start season', 'date': '2022-08-10'}
# {'_id': ObjectId('62f33a3378f6fd03efc1aece'), 'header': 'Pacioretty of Hurricanes to have surgery, likely out first half of season', 'subheader': 'Forward will need six months to recover for torn Achilles, was acquired from Golden Knights on July 13', 'date': '2022-08-09'}
# {'_id': ObjectId('62f33a3378f6fd03efc1aecf'), 'header': "Mailbag: Robertson's future, Islanders offseason, best in Metropolitan", 'subheader': "NHL.com's Dan Rosen answers weekly questions", 'date': '2022-08-10'}
# {'_id': ObjectId('62f33a3378f6fd03efc1aed0'), 'header': 'Trouba named Rangers captain, first since McDonagh in 2018', 'subheader': 'Defenseman 28th player to hold title in New York history', 'date': '2022-08-09'}
# {'_id': ObjectId('62f33a3378f6fd03efc1aed1'), 'header': 'Three questions facing Boston Bruins', 'subheader': "Marchand, McAvoy injuries, Montgomery's impact as new coach among concerns", 'date': '2022-08-10'}
# {'_id': ObjectId('62f33a3378f6fd03efc1aed2'), 'header': 'NHL Free Agent Tracker', 'subheader': 'Complete list of signings by team, available players', 'date': '2022-08-09'}
# {'_id': ObjectId('62f33a3378f6fd03efc1aed3'), 'header': 'DeBoer talks joining Stars, Pavelski as coach in Q&A with NHL.com', 'subheader': 'Discusses time working for Golden Knights, leading Sharks, Devils to Stanley Cup Final', 'date': '2022-08-10'}
# {'_id': ObjectId('62f33a3378f6fd03efc1aed4'), 'header': 'World Junior Championship roundup: Czechia defeats Slovakia on late goal', 'subheader': 'United States set to start tournament against Germany; Finland tops Latvia', 'date': '2022-08-09'}
# {'_id': ObjectId('62f33a3378f6fd03efc1aed5'), 'header': 'Top prospects for Boston Bruins', 'subheader': 'Lysell, Studnicka on cusp, Beecher likely to start in AHL', 'date': '2022-08-10'}
# {'_id': ObjectId('62f33a3378f6fd03efc1aed6'), 'header': 'Fantasy hockey mock draft 1.0', 'subheader': 'Results of first standard-league simulation for 2022-23; season preview podcasts', 'date': '2022-08-09'}
# {'_id': ObjectId('62f33a3378f6fd03efc1aed7'), 'header': '2022 World Junior Championship schedule', 'subheader': 'Canada set to play against Latvia in Edmonton', 'date': '2022-08-09'}
# {'_id': ObjectId('62f33a3378f6fd03efc1aed8'), 'header': 'State Your Case: Can Ovechkin score 50 again?', 'subheader': 'NHL.com writers debate whether Capitals forward can reach mark this season at age 37', 'date': '2022-08-09'}
# {'_id': ObjectId('62f33a3378f6fd03efc1aed9'), 'header': 'Boston Bruins fantasy projections for 2022-23', 'subheader': 'Pastrnak remains elite option; Swayman breakout candidate; Hall could be bargain', 'date': '2022-08-10'}
# {'_id': ObjectId('62f33a3378f6fd03efc1aeda'), 'header': 'Bergeron, Krejci each signs one-year contract with Bruins', 'subheader': 'Captain back for 19th season with Boston; fellow center returns after playing in Czech Republic', 'date': '2022-08-09'}
# {'_id': ObjectId('62f33a3378f6fd03efc1aedb'), 'header': 'Necas signs two-year contract with Hurricanes', 'subheader': 'Restricted free agent forward gets $6 million, had 40 points last season', 'date': '2022-08-09'}
# {'_id': ObjectId('62f33a3378f6fd03efc1aedc'), 'header': 'Top remaining NHL unrestricted free agents include Kadri, Kessel', 'subheader': 'Stastny, Subban also available', 'date': '2022-08-08'}
# {'_id': ObjectId('62f33a3378f6fd03efc1aedd'), 'header': 'Askarov working way up depth chart for Predators', 'subheader': "Goalie expected to play in AHL this season, will be 'really good player for us'", 'date': '2022-08-10'}
# {'_id': ObjectId('62f33a3378f6fd03efc1aede'), 'header': "Bergeron's fire still strong, ready to do 'something special' with Bruins", 'subheader': '37-year-old center returns to Boston for 19th season, teams up with Krejci again', 'date': '2022-08-08'}
# {'_id': ObjectId('62f33a3378f6fd03efc1aedf'), 'header': 'McDonagh excited by opportunity to play for Predators', 'subheader': "Defenseman was acquired from Lightning, sees Nashville as 'hungry for more and I want to be a part of it'", 'date': '2022-08-09'}
# {'_id': ObjectId('62f33a3378f6fd03efc1aee0'), 'header': 'Inside look at Arizona Coyotes', 'subheader': 'Focused on extended rebuild entering first season at Arizona State University', 'date': '2022-08-09'}
# {'_id': ObjectId('62f33a3378f6fd03efc1aee1'), 'header': 'Three questions facing Arizona Coyotes', 'subheader': 'Chychrun bouncing back amid trade rumors, 14-game road trip among concerns', 'date': '2022-08-09'}
# {'_id': ObjectId('62f33a3378f6fd03efc1aee2'), 'header': 'Hasek looks back at trade to Sabres that changed NHL career, life', 'subheader': "30 years later, Hall of Fame goalie discusses emergence in 'my second home'", 'date': '2022-08-07'}
# {'_id': ObjectId('62f33a3378f6fd03efc1aee3'), 'header': 'Zacha signs one-year contract with Bruins, avoids arbitration', 'subheader': 'Forward gets $3.5 million, had hearing scheduled for Thursday', 'date': '2022-08-09'}
# {'_id': ObjectId('62f33a3378f6fd03efc1aee4'), 'header': 'Top prospects for Arizona Coyotes', 'subheader': 'Cooley No. 3 pick in 2022 draft; McBain could see time in NHL this season', 'date': '2022-08-09'}
# {'_id': ObjectId('62f33a3378f6fd03efc1aee5'), 'header': 'Roy signs five-year, $15 million contract with Golden Knights', 'subheader': 'Forward was restricted free agent, had NHL career-high 39 points last season', 'date': '2022-08-08'}
# {'_id': ObjectId('62f33a3378f6fd03efc1aee6'), 'header': '2022 NHL Draft first-round pick signings tracker', 'subheader': 'Status of 32 players chosen in opening round', 'date': '2022-07-18'}
# {'_id': ObjectId('62f33a3378f6fd03efc1aee7'), 'header': 'Giroux, Gaudreau among new faces in new places for 2022-23 NHL season', 'subheader': 'Flyers host Senators on Nov. 12; Blue Jackets to visit Flames on Jan. 23', 'date': '2022-08-08'}
# {'_id': ObjectId('62f33a3378f6fd03efc1aee8'), 'header': 'Crouse signs five-year contract with Coyotes, avoids arbitration', 'subheader': 'Forward had hearing scheduled for Monday', 'date': '2022-08-08'}
# {'_id': ObjectId('62f33a3378f6fd03efc1aee9'), 'header': 'Trouba congratulated by teammates after being named Rangers captain', 'subheader': 'Panarin, Zibanejad among those to rally around defenseman on social media', 'date': '2022-08-09'}
# {'_id': ObjectId('62f33a3378f6fd03efc1aeea'), 'header': 'Arizona Coyotes fantasy projections for 2022-23', 'subheader': 'Keller most valuable overall player; Schmaltz worth monitoring in late rounds', 'date': '2022-08-09'}

# %%
articles = db.articles.find()
for article in articles:
    print(article['header'])
# Out:
# Inside look at Arizona Coyotes
# Trouba named Rangers captain, first since McDonagh in 2018
# 3 'Star' keys to success for United States against Germany at WJC
# State Your Case: Can Ovechkin score 50 again?
# Bergeron's fire still strong, ready to do 'something special' with Bruins
# NHL Free Agent Tracker
# World Junior Championship roundup: Czechia defeats Slovakia on late goal
# Three questions facing Arizona Coyotes
# Necas signs two-year contract with Hurricanes
# McDonagh excited by opportunity to play for Predators
# 2022 World Junior Championship schedule
# Hasek looks back at trade to Sabres that changed NHL career, life
# Bennett takes Stanley Cup to Alberta hometown, hangs with Mounties
# Zacha signs one-year contract with Bruins, avoids arbitration
# Bergeron, Krejci each signs one-year contract with Bruins
# Top remaining NHL unrestricted free agents include Kadri, Kessel
# NHL mascots skate with fans at American Dream
# Top prospects for Arizona Coyotes
# Roy signs five-year, $15 million contract with Golden Knights
# Giroux, Gaudreau among new faces in new places for 2022-23 NHL season
# Arizona Coyotes fantasy projections for 2022-23
# Crouse signs five-year contract with Coyotes, avoids arbitration
# Trouba congratulated by teammates after being named Rangers captain
# 2022 World Junior Championship rosters
# Inside look at Anaheim Ducks
# 2022 NHL Draft first-round pick signings tracker
# Three questions facing Anaheim Ducks
# 2022 World Junior Championship predictions
# Fantasy hockey mock draft 1.0
# Tullio poised to impress Oilers after learning value of hard work
# Inside look at Boston Bruins
# Pacioretty of Hurricanes to have surgery, likely out first half of season
# Mailbag: Robertson's future, Islanders offseason, best in Metropolitan
# Trouba named Rangers captain, first since McDonagh in 2018
# Three questions facing Boston Bruins
# NHL Free Agent Tracker
# DeBoer talks joining Stars, Pavelski as coach in Q&A with NHL.com
# World Junior Championship roundup: Czechia defeats Slovakia on late goal
# Top prospects for Boston Bruins
# Fantasy hockey mock draft 1.0
# 2022 World Junior Championship schedule
# State Your Case: Can Ovechkin score 50 again?
# Boston Bruins fantasy projections for 2022-23
# Bergeron, Krejci each signs one-year contract with Bruins
# Necas signs two-year contract with Hurricanes
# Top remaining NHL unrestricted free agents include Kadri, Kessel
# Askarov working way up depth chart for Predators
# Bergeron's fire still strong, ready to do 'something special' with Bruins
# McDonagh excited by opportunity to play for Predators
# Inside look at Arizona Coyotes
# Three questions facing Arizona Coyotes
# Hasek looks back at trade to Sabres that changed NHL career, life
# Zacha signs one-year contract with Bruins, avoids arbitration
# Top prospects for Arizona Coyotes
# Roy signs five-year, $15 million contract with Golden Knights
# 2022 NHL Draft first-round pick signings tracker
# Giroux, Gaudreau among new faces in new places for 2022-23 NHL season
# Crouse signs five-year contract with Coyotes, avoids arbitration
# Trouba congratulated by teammates after being named Rangers captain
# Arizona Coyotes fantasy projections for 2022-23
